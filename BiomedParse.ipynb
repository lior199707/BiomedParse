# %% [markdown]
# # BiomedParse Inference Demo Notebook
#
# Welcome to the demo notebook for BiomedParse, a comprehensive tool for biomedical image analysis. BiomedParse is designed to simultaneously handle segmentation, detection, and recognition tasks across major biomedical image modalities, providing a unified solution for complex image analysis in biomedical research.
#
# [[`Paper`](https://aka.ms/biomedparse-paper)] [[`Demo`](https://microsoft.github.io/BiomedParse/)] [[`Model`](https://huggingface.co/microsoft/BiomedParse)]  [[`Data`](https://huggingface.co/datasets/microsoft/BiomedParseData)]
#
# ## Model Checkpoint Access
#
# The BiomedParse model checkpoint is hosted on [HuggingFace](https://huggingface.co/microsoft/BiomedParse). To access the model:
#
# 1. Visit the [model page](https://huggingface.co/microsoft/BiomedParse).
# 2. Make sure to review and accept the terms of use to gain access to the checkpoint.
# 3. Retrieve your HuggingFace access token from your user profile.
#
# ## Setting Up Access
#
# To use the model, set your Hugging Face access token in the HF_TOKEN environment variable or as a Colab secret. This step ensures secure and authorized access to the model resources.

# %%
# Set your Hugging Face access token in your environment
# import os
# os.environ['HF_TOKEN'] = 'your_huggingface_access_token_here'

# Or, if you are using Google Colab, set HF_TOKEN on Colab secrets.

# %%
from google.colab import output

# Prompt the user to input their Hugging Face token securely
token = input("Please enter your Hugging Face token: ")
output.clear()  # Clears the output for security

# Save the token as an environment variable
import os
os.environ["HF_TOKEN"] = token

# %%
print(os.environ.get("HF_TOKEN"))  # Should display your token
# Out:
# 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

# %%
from google.colab import userdata
import huggingface_hub

huggingface_hub.login(os.environ.get("HF_TOKEN"))
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
from huggingface_hub import hf_hub_download

model_file = hf_hub_download(repo_id="microsoft/BiomedParse", filename="biomedparse_v1.pt", local_dir="pretrained")

print(f"Downloaded model file to: {model_file}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# biomedparse_v1.pt:   0%|          | 0.00/1.80G [00:00<?, ?B/s]
# Downloaded model file to: pretrained/biomedparse_v1.pt

# %% [markdown]
# ## Environment Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/microsoft/BiomedParse
# Out:
# Cloning into 'BiomedParse'...
# remote: Enumerating objects: 1546, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 1546 (delta 79), reused 125 (delta 68), pack-reused 1401 (from 1)
# Receiving objects: 100% (1546/1546), 651.58 MiB | 23.57 MiB/s, done.
# Resolving deltas: 100% (450/450), done.
# Updating files: 100% (582/582), done.
# Filtering content: 100% (45/45), 69.68 MiB | 40.29 MiB/s, done.

# %%
# !pip install -r BiomedParse/assets/requirements/requirements.txt
# Out:
# Collecting git+https://github.com/MaureenZOU/detectron2-xyz.git (from -r BiomedParse/assets/requirements/requirements.txt (line 33))
#   Cloning https://github.com/MaureenZOU/detectron2-xyz.git to /tmp/pip-req-build-78qb6wku
#   Running command git clone --filter=blob:none --quiet https://github.com/MaureenZOU/detectron2-xyz.git /tmp/pip-req-build-78qb6wku
#   Resolved https://github.com/MaureenZOU/detectron2-xyz.git to commit 42121d75e10d9f858f3a91b6a39f5722c02868f0
#   Preparing metadata (setup.py) ... done
# Collecting pillow==9.4.0 (from -r BiomedParse/assets/requirements/requirements.txt (line 1))
#   Downloading Pillow-9.4.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.3 kB)
# Collecting opencv-python==4.8.1.78 (from -r BiomedParse/assets/requirements/requirements.txt (line 2))
#   Downloading opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting pyyaml==6.0.1 (from -r BiomedParse/assets/requirements/requirements.txt (line 3))
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting json_tricks==3.17.3 (from -r BiomedParse/assets/requirements/requirements.txt (line 4))
#   Downloading json_tricks-3.17.3-py2.py3-none-any.whl.metadata (16 kB)
# Collecting yacs==0.1.8 (from -r BiomedParse/assets/requirements/requirements.txt (line 5))
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Collecting scikit-learn==1.3.1 (from -r BiomedParse/assets/requirements/requirements.txt (line 6))
#   Downloading scikit_learn-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting pandas==2.0.3 (from -r BiomedParse/assets/requirements/requirements.txt (line 7))
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting timm==0.4.12 (from -r BiomedParse/assets/requirements/requirements.txt (line 8))
#   Downloading timm-0.4.12-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (from -r BiomedParse/assets/requirements/requirements.txt (line 9)) (1.26.4)
# Requirement already satisfied: einops==0.8.0 in /usr/local/lib/python3.10/dist-packages (from -r BiomedParse/assets/requirements/requirements.txt (line 10)) (0.8.0)
# Collecting fvcore==0.1.5.post20221221 (from -r BiomedParse/assets/requirements/requirements.txt (line 11))
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers==4.34.0 (from -r BiomedParse/assets/requirements/requirements.txt (line 12))
#   Downloading transformers-4.34.0-py3-none-any.whl.metadata (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.5/121.5 kB 8.7 MB/s eta 0:00:00
# Collecting sentencepiece==0.1.99 (from -r BiomedParse/assets/requirements/requirements.txt (line 13))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting ftfy==6.1.1 (from -r BiomedParse/assets/requirements/requirements.txt (line 14))
#   Downloading ftfy-6.1.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting regex==2023.10.3 (from -r BiomedParse/assets/requirements/requirements.txt (line 15))
#   Downloading regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.7 MB/s eta 0:00:00
# Collecting nltk==3.8.1 (from -r BiomedParse/assets/requirements/requirements.txt (line 16))
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting mpi4py==3.1.5 (from -r BiomedParse/assets/requirements/requirements.txt (line 17))
#   Downloading mpi4py-3.1.5.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 50.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting vision-datasets==0.2.2 (from -r BiomedParse/assets/requirements/requirements.txt (line 18))
#   Downloading vision_datasets-0.2.2-py3-none-any.whl.metadata (14 kB)
# Collecting cython==3.0.2 (from -r BiomedParse/assets/requirements/requirements.txt (line 19))
#   Downloading Cython-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Collecting pycocotools==2.0.7 (from -r BiomedParse/assets/requirements/requirements.txt (line 20))
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting diffdist==0.1 (from -r BiomedParse/assets/requirements/requirements.txt (line 21))
#   Downloading diffdist-0.1.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit-image==0.21.0 (from -r BiomedParse/assets/requirements/requirements.txt (line 25))
#   Downloading scikit_image-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting mup==1.0.0 (from -r BiomedParse/assets/requirements/requirements.txt (line 26))
#   Downloading mup-1.0.0.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting accelerate==0.23.0 (from -r BiomedParse/assets/requirements/requirements.txt (line 27))
#   Downloading accelerate-0.23.0-py3-none-any.whl.metadata (18 kB)
# Collecting kornia==0.7.0 (from -r BiomedParse/assets/requirements/requirements.txt (line 28))
#   Downloading kornia-0.7.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting deepspeed==0.10.3 (from -r BiomedParse/assets/requirements/requirements.txt (line 29))
#   Downloading deepspeed-0.10.3.tar.gz (867 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.3/867.3 kB 51.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting infinibatch==0.1.1 (from -r BiomedParse/assets/requirements/requirements.txt (line 31))
#   Downloading infinibatch-0.1.1-py3-none-any.whl.metadata (16 kB)
# Collecting open-clip-torch==2.26.1 (from -r BiomedParse/assets/requirements/requirements.txt (line 32))
#   Downloading open_clip_torch-2.26.1-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.1->-r BiomedParse/assets/requirements/requirements.txt (line 6)) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.1->-r BiomedParse/assets/requirements/requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.1->-r BiomedParse/assets/requirements/requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->-r BiomedParse/assets/requirements/requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->-r BiomedParse/assets/requirements/requirements.txt (line 7)) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->-r BiomedParse/assets/requirements/requirements.txt (line 7)) (2024.2)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.4.12->-r BiomedParse/assets/requirements/requirements.txt (line 8)) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.4.12->-r BiomedParse/assets/requirements/requirements.txt (line 8)) (0.20.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fvcore==0.1.5.post20221221->-r BiomedParse/assets/requirements/requirements.txt (line 11)) (4.66.6)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore==0.1.5.post20221221->-r BiomedParse/assets/requirements/requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore==0.1.5.post20221221->-r BiomedParse/assets/requirements/requirements.txt (line 11)) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore==0.1.5.post20221221->-r BiomedParse/assets/requirements/requirements.txt (line 11))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (0.26.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (2.32.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12))
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (0.4.5)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy==6.1.1->-r BiomedParse/assets/requirements/requirements.txt (line 14)) (0.2.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk==3.8.1->-r BiomedParse/assets/requirements/requirements.txt (line 16)) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from vision-datasets==0.2.2->-r BiomedParse/assets/requirements/requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0.7->-r BiomedParse/assets/requirements/requirements.txt (line 20)) (3.8.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.21.0->-r BiomedParse/assets/requirements/requirements.txt (line 25)) (3.4.2)
# Requirement already satisfied: imageio>=2.27 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.21.0->-r BiomedParse/assets/requirements/requirements.txt (line 25)) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.21.0->-r BiomedParse/assets/requirements/requirements.txt (line 25)) (2024.9.20)
# Collecting PyWavelets>=1.1.1 (from scikit-image==0.21.0->-r BiomedParse/assets/requirements/requirements.txt (line 25))
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: lazy_loader>=0.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.21.0->-r BiomedParse/assets/requirements/requirements.txt (line 25)) (0.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from mup==1.0.0->-r BiomedParse/assets/requirements/requirements.txt (line 26)) (0.13.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.23.0->-r BiomedParse/assets/requirements/requirements.txt (line 27)) (5.9.5)
# Collecting hjson (from deepspeed==0.10.3->-r BiomedParse/assets/requirements/requirements.txt (line 29))
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting ninja (from deepspeed==0.10.3->-r BiomedParse/assets/requirements/requirements.txt (line 29))
#   Downloading ninja-1.11.1.2-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.10.3->-r BiomedParse/assets/requirements/requirements.txt (line 29)) (9.0.0)
# Collecting pydantic<2.0.0 (from deepspeed==0.10.3->-r BiomedParse/assets/requirements/requirements.txt (line 29))
#   Downloading pydantic-1.10.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.6/152.6 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (3.1.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (2.17.1)
# Collecting iopath>=0.1.7 (from fvcore==0.1.5.post20221221->-r BiomedParse/assets/requirements/requirements.txt (line 11))
#   Downloading iopath-0.1.9-py3-none-any.whl.metadata (370 bytes)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (1.0.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (3.0.3)
# Collecting omegaconf>=2.1 (from detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33))
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting hydra-core>=1.1 (from detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33))
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting black==21.4b2 (from detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33))
#   Downloading black-21.4b2-py3-none-any.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 5.2 MB/s eta 0:00:00
# Collecting appdirs (from black==21.4b2->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: toml>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from black==21.4b2->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (0.10.2)
# Collecting pathspec<1,>=0.8.1 (from black==21.4b2->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33))
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting mypy-extensions>=0.4.3 (from black==21.4b2->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (4.12.2)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath>=0.1.7->fvcore==0.1.5.post20221221->-r BiomedParse/assets/requirements/requirements.txt (line 11))
#   Downloading portalocker-3.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.7->-r BiomedParse/assets/requirements/requirements.txt (line 20)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.7->-r BiomedParse/assets/requirements/requirements.txt (line 20)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.7->-r BiomedParse/assets/requirements/requirements.txt (line 20)) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.7->-r BiomedParse/assets/requirements/requirements.txt (line 20)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.7->-r BiomedParse/assets/requirements/requirements.txt (line 20)) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.3->-r BiomedParse/assets/requirements/requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12)) (2024.8.30)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers==4.34.0->-r BiomedParse/assets/requirements/requirements.txt (line 12))
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12->-r BiomedParse/assets/requirements/requirements.txt (line 8)) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12->-r BiomedParse/assets/requirements/requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.4->timm==0.4.12->-r BiomedParse/assets/requirements/requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (75.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6->-r BiomedParse/assets/requirements/requirements.txt (line 33)) (3.0.2)
# Downloading Pillow-9.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 91.7 MB/s eta 0:00:00
# Downloading opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 14.2 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 41.4 MB/s eta 0:00:00
# Downloading json_tricks-3.17.3-py2.py3-none-any.whl (27 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading scikit_learn-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 109.4 MB/s eta 0:00:00
# Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 108.6 MB/s eta 0:00:00
# Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 30.1 MB/s eta 0:00:00
# Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 107.8 MB/s eta 0:00:00
# Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.7 MB/s eta 0:00:00
# Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 4.4 MB/s eta 0:00:00
# Downloading regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.9/773.9 kB 51.2 MB/s eta 0:00:00
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 77.1 MB/s eta 0:00:00
# Downloading vision_datasets-0.2.2-py3-none-any.whl (39 kB)
# Downloading Cython-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 91.2 MB/s eta 0:00:00
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 35.4 MB/s eta 0:00:00
# Downloading scikit_image-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.3 MB/s eta 0:00:00
# Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 20.8 MB/s eta 0:00:00
# Downloading kornia-0.7.0-py2.py3-none-any.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.7/705.7 kB 52.7 MB/s eta 0:00:00
# Downloading infinibatch-0.1.1-py3-none-any.whl (32 kB)
# Downloading open_clip_torch-2.26.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 74.2 MB/s eta 0:00:00
# Downloading black-21.4b2-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 12.1 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.8 MB/s eta 0:00:00
# Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.0 MB/s eta 0:00:00
# Downloading pydantic-1.10.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 103.0 MB/s eta 0:00:00
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 105.5 MB/s eta 0:00:00
# Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 98.6 MB/s eta 0:00:00
# Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 26.3 MB/s eta 0:00:00
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 4.8 MB/s eta 0:00:00
# Downloading ninja-1.11.1.2-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 33.8 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading portalocker-3.0.0-py3-none-any.whl (19 kB)
# Building wheels for collected packages: fvcore, mpi4py, diffdist, mup, deepspeed, detectron2, antlr4-python3-runtime
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61396 sha256=1eef43c46452c763e643935eb9566691e2d33e101461e638a7c4ad363bb1fcd8
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for mpi4py (pyproject.toml) ... done
#   Created wheel for mpi4py: filename=mpi4py-3.1.5-cp310-cp310-linux_x86_64.whl size=2746523 sha256=28842f36eef9d350174eda1251b2dc5a74337f656098ce26ca73b134cb299b77
#   Stored in directory: /root/.cache/pip/wheels/18/2b/7f/c852523089e9182b45fca50ff56f49a51eeb6284fd25a66713
#   Building wheel for diffdist (setup.py) ... done
#   Created wheel for diffdist: filename=diffdist-0.1-py3-none-any.whl size=6534 sha256=bc25ee1fc4e2594c216fb3644fd0a230f7aa178b95676560dce582a68b60fee6
#   Stored in directory: /root/.cache/pip/wheels/f1/29/f6/5331a14ab74e769799b76eb32460f447c7feb7375a16b07854
#   Building wheel for mup (setup.py) ... done
#   Created wheel for mup: filename=mup-1.0.0-py3-none-any.whl size=23629 sha256=4c63ac47e0cc96ebffc792dc319f7fd819cece85ce0bce58d7d1bb5e5c172f93
#   Stored in directory: /root/.cache/pip/wheels/f4/c8/88/3c23a3d10c50053b6552d2d30aee5b53ba89a47f742420036c
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.10.3-py3-none-any.whl size=907833 sha256=090636a80e0bf56ddb2eed1ce7ee40cf3fbf41a1ec285e6f7087fe469bc4ce1c
#   Stored in directory: /root/.cache/pip/wheels/d8/8e/fe/bd6467e058672bf39888e67b763f706053f6f969fe0542423d
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=6342462 sha256=1564dd64a00a5d55b9ca144437a10267481e71c61b2681204495b789a39f7c7d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o5vyozo2/wheels/7f/01/26/a8173423e3f7366079469ba614da45c1a875b4cd72bc269568
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=99903950bf5c5d1cca6e39d299b5dd400f0c749e2a2f63d76036897c1821b70f
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built fvcore mpi4py diffdist mup deepspeed detectron2 antlr4-python3-runtime
# Installing collected packages: sentencepiece, json_tricks, hjson, diffdist, appdirs, antlr4-python3-runtime, regex, pyyaml, PyWavelets, pydantic, portalocker, pillow, pathspec, opencv-python, ninja, mypy-extensions, mpi4py, infinibatch, ftfy, cython, yacs, vision-datasets, scikit-learn, pandas, omegaconf, nltk, iopath, huggingface-hub, black, tokenizers, scikit-image, pycocotools, kornia, hydra-core, fvcore, deepspeed, accelerate, transformers, timm, mup, detectron2, open-clip-torch
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.0
#     Uninstalling sentencepiece-0.2.0:
#       Successfully uninstalled sentencepiece-0.2.0
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.9.11
#     Uninstalling regex-2024.9.11:
#       Successfully uninstalled regex-2024.9.11
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.3
#     Uninstalling pydantic-2.10.3:
#       Successfully uninstalled pydantic-2.10.3
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.0.0
#     Uninstalling pillow-11.0.0:
#       Successfully uninstalled pillow-11.0.0
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.11
#     Uninstalling Cython-3.0.11:
#       Successfully uninstalled Cython-3.0.11
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.1
#     Uninstalling nltk-3.9.1:
#       Successfully uninstalled nltk-3.9.1
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.26.3
#     Uninstalling huggingface-hub-0.26.3:
#       Successfully uninstalled huggingface-hub-0.26.3
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.24.0
#     Uninstalling scikit-image-0.24.0:
#       Successfully uninstalled scikit-image-0.24.0
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.8
#     Uninstalling pycocotools-2.0.8:
#       Successfully uninstalled pycocotools-2.0.8
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.1.1
#     Uninstalling accelerate-1.1.1:
#       Successfully uninstalled accelerate-1.1.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.3
#     Uninstalling transformers-4.46.3:
#       Successfully uninstalled transformers-4.46.3
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.12
#     Uninstalling timm-1.0.12:
#       Successfully uninstalled timm-1.0.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.20 requires pydantic>=2.7.0, but you have pydantic 1.10.19 which is incompatible.
# diffusers 0.31.0 requires huggingface-hub>=0.23.2, but you have huggingface-hub 0.17.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.0.3 which is incompatible.
# langchain 0.3.9 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.19 which is incompatible.
# langchain-core 0.3.21 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.19 which is incompatible.
# mizani 0.13.0 requires pandas>=2.2.0, but you have pandas 2.0.3 which is incompatible.
# plotnine 0.14.3 requires pandas>=2.2.0, but you have pandas 2.0.3 which is incompatible.
# sentence-transformers 3.2.1 requires huggingface-hub>=0.20.0, but you have huggingface-hub 0.17.3 which is incompatible.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.34.0 which is incompatible.
# xarray 2024.10.0 requires pandas>=2.1, but you have pandas 2.0.3 which is incompatible.
# Successfully installed PyWavelets-1.8.0 accelerate-0.23.0 antlr4-python3-runtime-4.9.3 appdirs-1.4.4 black-21.4b2 cython-3.0.2 deepspeed-0.10.3 detectron2-0.6 diffdist-0.1 ftfy-6.1.1 fvcore-0.1.5.post20221221 hjson-3.1.0 huggingface-hub-0.17.3 hydra-core-1.3.2 infinibatch-0.1.1 iopath-0.1.9 json_tricks-3.17.3 kornia-0.7.0 mpi4py-3.1.5 mup-1.0.0 mypy-extensions-1.0.0 ninja-1.11.1.2 nltk-3.8.1 omegaconf-2.3.0 open-clip-torch-2.26.1 opencv-python-4.8.1.78 pandas-2.0.3 pathspec-0.12.1 pillow-9.4.0 portalocker-3.0.0 pycocotools-2.0.7 pydantic-1.10.19 pyyaml-6.0.1 regex-2023.10.3 scikit-image-0.21.0 scikit-learn-1.3.1 sentencepiece-0.1.99 timm-0.4.12 tokenizers-0.14.1 transformers-4.34.0 vision-datasets-0.2.2 yacs-0.1.8

# %% [markdown]
# # Restart Colab Runtime

# %%
# Make sure to restart Colab runtime after installing dependencies
import os
try:
    import google.colab
    os._exit(0)
except ImportError:
    pass

# %%
import os
os.chdir('/content/BiomedParse')
print(os.getcwd())
# Out:
# /content/BiomedParse

# %% [markdown]
# ## Load the model weights

# %%
from PIL import Image
import torch
import argparse
import numpy as np
from modeling.BaseModel import BaseModel
from modeling import build_model
from utilities.distributed import init_distributed # changed from utils
from utilities.arguments import load_opt_from_config_files
from utilities.constants import BIOMED_CLASSES
from inference_utils.inference import interactive_infer_image

conf_files = "configs/biomedparse_inference.yaml"
opt = load_opt_from_config_files([conf_files])
opt = init_distributed(opt)

model_file = "../pretrained/biomedparse_v1.pt"

model = BaseModel(opt, build_model(opt)).from_pretrained(model_file).eval().cuda()
with torch.no_grad():
    model.model.sem_seg_head.predictor.lang_encoder.get_text_embeddings(BIOMED_CLASSES + ["background"], is_eval=True)
# Out:
# Deformable Transformer Encoder is not available.
# /usr/local/lib/python3.10/dist-packages/kornia/feature/lightglue.py:30: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# Downloading tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:484: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location=map_location)
# /content/BiomedParse/modeling/BaseModel.py:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_dir, map_location=self.opt['device'])
# WARNING:utilities.model:$UNUSED$ criterion.empty_weight, Ckpt Shape: torch.Size([17])

# %% [markdown]
# # Run Inference

# %%
# RGB image input of shape (H, W, 3). Currently only batch size 1 is supported.
image = Image.open('examples/Part_1_516_pathology_breast.png', formats=['png'])
image = image.convert('RGB')

# text prompts querying objects in the image. Multiple ones can be provided.
prompts = ['neoplastic cells', 'inflammatory cells']

pred_mask = interactive_infer_image(model, image, prompts)
pred_mask.shape
# Out:
# (2, 1024, 1024)

# %%
# load ground truth mask
gt_masks = []
for prompt in prompts:
    gt_mask = Image.open(f"examples/Part_1_516_pathology_breast_{prompt.replace(' ', '+')}.png", formats=['png'])
    gt_mask = 1*(np.array(gt_mask.convert('RGB'))[:,:,0] > 0)
    gt_masks.append(gt_mask)

# prediction with ground truth mask
for i, pred in enumerate(pred_mask):
    gt = gt_masks[i]
    dice = (1*(pred>0.5) & gt).sum() * 2.0 / (1*(pred>0.5).sum() + gt.sum())
    print(f'Dice score for {prompts[i]}: {dice:.4f}')
# Out:
# Dice score for neoplastic cells: 0.9022
# Dice score for inflammatory cells: 0.9011

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.patches as mpatches

def overlay_masks(image, masks, colors):
    overlay = image.copy()
    overlay = np.array(overlay, dtype=np.uint8)
    for mask, color in zip(masks, colors):
        overlay[mask > 0] = (overlay[mask > 0] * 0.4 + np.array(color) * 0.6).astype(np.uint8)
    return Image.fromarray(overlay)

def generate_colors(n):
    cmap = plt.get_cmap('tab10')
    colors = [tuple(int(255 * val) for val in cmap(i)[:3]) for i in range(n)]
    return colors

original_image = Image.open('examples/Part_1_516_pathology_breast.png').convert('RGB')

colors = generate_colors(len(prompts))

pred_overlay = overlay_masks(original_image, [1*(pred_mask[i] > 0.5) for i in range(len(prompts))], colors)

gt_overlay = overlay_masks(original_image, gt_masks, colors)

legend_patches = [mpatches.Patch(color=np.array(color) / 255, label=prompt) for color, prompt in zip(colors, prompts)]

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].imshow(original_image)
axes[0].set_title("Original Image")
axes[0].axis('off')

axes[1].imshow(pred_overlay)
axes[1].set_title("Predictions")
axes[1].axis('off')
axes[1].legend(handles=legend_patches, loc='upper right', fontsize='small')

axes[2].imshow(gt_overlay)
axes[2].set_title("Ground Truth")
axes[2].axis('off')
axes[2].legend(handles=legend_patches, loc='upper right', fontsize='small')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Testing model n wire images

# %% [markdown]
# # Test

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## general functions

# %%
def overlay_masks(image, masks, colors):
    overlay = image.copy()
    overlay = np.array(overlay, dtype=np.uint8)
    for mask, color in zip(masks, colors):
        overlay[mask > 0] = (overlay[mask > 0] * 0.4 + np.array(color) * 0.6).astype(np.uint8)
    return Image.fromarray(overlay)

# text prompts querying objects in the image. Multiple ones can be provided.
def generate_colors(n):
    cmap = plt.get_cmap('tab10')
    colors = [tuple(int(255 * val) for val in cmap(i)[:3]) for i in range(n)]
    return colors

def predict_and_show(prompts, image):
    colors = generate_colors(len(prompts))
    legend_patches = [mpatches.Patch(color=np.array(color) / 255, label=prompt) for color, prompt in zip(colors, prompts)]
    pred_mask = interactive_infer_image(model, image, prompts)
    pred_overlay = overlay_masks(image, [1*(pred_mask[i] > 0.5) for i in range(len(prompts))], colors)
    fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    ax.imshow(pred_overlay)  # Replace with the overlay you want to display
    ax.set_title("Predictions")
    ax.axis('off')
    ax.legend(handles=legend_patches, loc='upper right', fontsize='small')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Testing on wire images

# %%
WIRE_IMG_PATH = '../drive/MyDrive/Img/wire_images_video_8/frame_0002.png'

wire_image = Image.open(WIRE_IMG_PATH).convert('RGB')
# cable, line, string, artery, cord, wire
prompts = ['artery', 'cord' , 'wire']
prompts2 = ['line']

predict_and_show(prompts2, wire_image)

# %% [markdown]
# ## Testing on artery images

# %%
ARTERY_IMG_PATH = '../drive/MyDrive/Img/wire_images_video_1/artery_img.png'

artery_image = Image.open(ARTERY_IMG_PATH).resize((1024,1024)).convert('RGB')
prompts = ['artery']

predict_and_show(prompts, artery_image)

# %%
ARTERY_IMG_PATH = '../drive/MyDrive/Img/wire_images_video_1/artery_img_1.png'

artery_image = Image.open(ARTERY_IMG_PATH).resize((1024,1024)).convert('RGB')
prompts = ['artery in ultrasound']

predict_and_show(prompts, artery_image)

# %%
# In the picture: A = artery, V = vein
ARTERY_IMG_PATH = '../drive/MyDrive/Img/wire_images_video_1/artery_img_2.png'

artery_image = Image.open(ARTERY_IMG_PATH).resize((1024,1024)).convert('RGB')
prompts = ['artery in ultrasound']

predict_and_show(prompts, artery_image)

# %% [markdown]
# ## Model Playground

# %%
# Load the image
image_path = '../drive/MyDrive/Img/wire_images_video_1/artery_img.png'  # Replace with your image path
image = Image.open(image_path)

# Resize the image to 1024x1024
resized_image = image.resize((1024, 1024), Image.ANTIALIAS)
# Out:
# <ipython-input-29-821d117b75c7>:6: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   resized_image = image.resize((1024, 1024), Image.ANTIALIAS)

# %%
import matplotlib.patches as mpatches
# image_path = 'examples/Part_1_516_pathology_breast.png'
# image_path = '../drive/MyDrive/Img/wire_images_video_1/frame_0008.png'
image_path = '../drive/MyDrive/Img/wire_images_video_1/artery_img.png'

# wire_image = Image.open(imag_path).convert('RGB')
wire_image = Image.open(image_path).resize((1024,1024)).convert('RGB')
prompts = ['neoplastic cells', 'inflammatory cells']
prompts = ['artery']



colors = generate_colors(len(prompts))
legend_patches = [mpatches.Patch(color=np.array(color) / 255, label=prompt) for color, prompt in zip(colors, prompts)]

pred_mask = interactive_infer_image(model, wire_image, prompts)
pred_mask.shape
pred_overlay = overlay_masks(wire_image, [1*(pred_mask[i] > 0.5) for i in range(len(prompts))], colors)
# plt.imshow(pred_overlay)
# plt.axis('off')  # Optional: to hide the axis
# plt.show()

# Plot the single image and overlays
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.imshow(pred_overlay)  # Replace with the overlay you want to display
ax.set_title("Predictions")
ax.axis('off')
ax.legend(handles=legend_patches, loc='upper right', fontsize='small')

plt.tight_layout()
plt.show()
